# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import math

# %% [markdown]
# Considering the orbits to be circular ones, find the following:
# 1. Average orbit radius (r1 and r2)
# 2. Circular velocity (calculate from the previous lab)

# %%
r_2 = 200000000
r_1 = 150000000

v_1 = 20
v_2 = 30

# %%
# рисуем 2 круговые орбиты по известным радиусам

# %%
# Calculate velocity impulse here
# https://ru.wikipedia.org/wiki/Гомановская_траектория

v_p = 
dv_1 = 
dv_2 = 
v_sum =

# %%
# Calculate Hohmann ellipse parameters here
# from pdf file

ec = 
a = 
c = ec * a
b = (a*a - c*c)**0.5

center = a - r_1

# %%
# Calculations for Hohmann trajectory

# %%
# Drawing trajectory and both orbits

# %%
# Calculating mass consumption from pdf file
# NK-33 rocket engine, 3250 m/s
# SSME rocket engine, 4440 m/s
# Space Shuttle Solid Rocket Booster, 2500 m/s
# Liquid oxygen-liquid hydrogen, 4400 m/s

m =

# %%
# Calculating transfer time from pdf file

t =

# %%
# Область применения  и особенности Гомановского перелёта
